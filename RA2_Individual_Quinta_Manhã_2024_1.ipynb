# %% [markdown]
# <a href="https://colab.research.google.com/github/AndreEllerTrova/andre.cal3/blob/main/RA2_Individual_Quinta_Manh%C3%A3_2024_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Avaliação em INDIVIDUAL RA2 - 2024-1
#
# **Antes de começar, leia estas instruções cuidadosamente.**
# Esta avaliação é individual. Você poderá consultar qualquer fonte disponível na biblioteca, suas anotações ou na internet. Mas, não poderá consultar outras pessoas.
#
# **Não existirão prorrogações de prazo de entrega.** Se programe para entregar sua avaliação 5 minutos antes do fim do prazo para evitar imprevistos de última hora.
#
# **Trabalhos idênticos entregues por pessoas, diferentes, serão zerados.** Todos os trabalhos serão submetidos a verificação de plágio. Isso significa que respostas copiadas e coladas de sistemas de inteligência artificial que sejam classificados com semelhança maior que 70% também serão zerados. Qualquer diagnóstico indicativo de plágio acima de 70% também irá provocar o zeramento da avaliação.
#
# Para que sua avaliação seja considerada **todos os trabalhos serão entregues em uma cópia deste caderno de atividades na forma de um link postado no AVA da instituição (Canvas)** apenas no local correspondente a essa entrega na avaliação. Qualquer link enviado em comentários, e-mails, mensagens de Whatsapp, ou qualquer outro meio eletrônico serão ignorados provocando o zeramento desta avaliação.
#
# Entrega será realizada com a postagem de um link para um ambiente de execução, no AVA da institução. Neste link o **seu caderno deve permitir ser executado (permissão de leitor)**. Serão aceitos links diretos ao ambiente do Google Colaboratory, ou Links a um caderno do Google Colaboratory que tenha sido **salvo pelo próprio Google Colaboratory** no GitHub. Links para outro ambiente, ou que requeiram qualquer tipo de **download, cliques extras, ou ainda, que requeiram aprovação para acesso, provocarão o zeramento desta avaliação**.
#
# Antes de enviar o seu trabalho, teste o compartilhamento em uma aba anônima do seu navegador web preferido.
#
# Todos os enunciados devem ser preservados e você deverá inserir uma célula de textos com o **seu nome, logo após esta célula de texto de instruções**.
#
# **Qualquer alteração do caderno contendo as suas respostas que seja registrada após a data de postagem provocará a anulação da avaliação**.
#
# Você poderá usar, nas suas respostas, só e somente só, a **linguagem Python** limitada ao uso das seguintes bibliotecas: **math, numpy, sympy, matplotlib, ipWidgets e IPython**. O uso de qualquer biblioteca não listada nestas instruções irá provocar o zeramento da avaliação.
#
# **Todo e qualquer gráfico que usar nas suas respostas deverá ser criado usando o Python**.
#
# **Todas as expressões matemáticas deverão ser escritas em uma célula de textos do Google Colaboratory, usando Latex, de forma que estas expressões sejam renderizadas com notação matemática**.
#
# Todas as suas simplificações e observações serão levadas em consideração. Contudo, lembre-se que estas questões devem ser resolvidas, sempre que exigido na questão, com álgebra e apenas álgebra. Não é permitido usar qualquer técnica matemática baseada em integração, cálculo numérico, séries de Taylor. de Leibntz ou de qualquer outro tipo, ou ainda conhecimento matemático que fuja dos conteúdos apresenados em aula referentes ao estudo de limites e derivação.
#
# **Caso a questão não especifique o uso de álgebra, você poderá utilizar técnicas numéricas para calcular máximos, mínimos ou encontrar o polinômio referente a um dado conjunto de pontos.**
#
# **Esta avaliação está limitada a conteúdo de técnicas, regras e conceitos de derivação**. Porém, pode ocorrer a necessidade do uso dos conceitos e técnicas de limites para a solução das questões.
#
# Se você encontrar algo errado nesta avaliação simplesmente anote suas observações na própria questão. Suas observações serão consideradas durante a avaliação e, em caso de pertinência, poderão encejar a anulação do item, ou da questão, a critério do professor.
#
# **Lembrem-se a interpretação faz parte da questão.**
#
#
# **Rubrica de Avaliação**: os valores que serão atribuidos a cada questão estão especificados nas próprias questões.

# %% [markdown]
# # Questão 1 - Até 1 ponto
# A imagem a seguir contém os gráficos da primeira $(d/dx)$ e segunda $(d^2/dx^2)$ derivadas de uma função desconhecidada. Sua tarefa é identificar os pontos de máximo, mínimo e inflexão da função desconhecida que, por ventura, existam no intervalo apresentado.
# ![image.png](data:image/png;base64,...)
#
# O ponto 2.33 é maximo
#
# O ponto 3.00 minimo
#
# O ponto 2.67 inflexao
#
# Caso haja algum problema com a visualização da imagem, a mesma está disponível no link a seguir
# https://drive.google.com/file/d/1MK7FX7q3CCFkCj2bvKJxebx1TVe-iCeZ/view?usp=sharing
#
# **Rubrica de Avaliação**: até um ponto pela identicação correta da natureza dos pontos críticos, caso eles existam, ou não.

# %% [markdown]
# #Questão 2 - até 2 pontos
# Usando apenas álgebra, encontre os pontos críticos das funções a seguir determinando a natureza destes pontos críticos, caso eles existam:
#
# a) $f(x)=x^4-4x^3+4x^2$
#
# minimo local em ${x}$ = 0.
#
# maximo local em ${x}$ = 1.
#
# ponto de inflexcao em ${x}$ = 2.
#
#
# b)$f(x)=x^4(x-3)^2$</br>
# minimo local em ${x}$ = 0
#
# maximo local em ${x}$ = 2
#
# ponto de inflexcao ${x}$ = 3
#
#
# **Rubrica de Avaliação**: até dois pontos pela identicação correta da natureza dos pontos críticos, caso eles existam, ou não. Caso um ponto crítico seja identificado de forma errada ele anulará o ponto correpondente ao subitem (a ou b) da questão.

# %% [markdown]
# # Questão 3 - Vale até 4 Pontos
#
# Usando apenas ferramentas computacionais e gráficos, faça a análise dos pontos críticos das seguintes funções:
#
# a)$f(x)=e^{2x}−e^x$
#
# o unico ponto critico e ${x}$ = In ($\frac{1}{2}$) tendo em vista que $e^x$ é sempre positivo, então a única solução real é quando $2e^x$ -1 = 0
#
# ![image.png](data:image/png;base64,...)
# x = -0.6931471805599453
#
# f(x) = -0.250000000000000
#
# f'(x) = 0
#
# f''(x) = 0.500000000000000
#
#
# b)$f(x)=e^x+x$
#
# Nao tem ponto critico para ${e^x}$ = -1 pois ${e^x}$ é sempre positivo para todos os valores de ${x}$
#
# Portanto, a função não possui pontos críticos reais.
#
# **Atenção**: O tempo é importante, então escolha, entre usar ferramentas computacionais ou gráficas. Independente da sua escolha você deverá escrever a resposta em uma célula de textos.

# %% [markdown]
# # Questão 4 - Vale até 2 pontos
# As margens superior e inferior de um pôster têm cada uma 6 cm, e as margens laterais têm cada uma 4 cm. Se a área do material impresso no pôster (isto é, a área entre as margens) é fixada em 384 cm², encontre as dimensões do pôster com a menor área total.
#
# As dimencoes do poster com a menor area total sao 16cm $*$ 24cm, e a area total e $864cm^2$
#
# **Rubrica de Avaliação**: até dois pontos se encontrar a área corretamente.

# %% [markdown]
# # Questão 4 - Alternativa - Vale até 2 pontos
#
# Em uma fábrica, latas de sopa cilíndricas devem ser fabricadas para conter um volume dado $V$. Não há desperdício de material na corte da parte vertical de cada lata ( o lado do cilíndro), mas cada tampa e fundo, que são círculos de raio $r$, são cortados de um quadrado que mede $2r$ unidades de lado. Assim, o material usado para fabricar cada lata de sopa tem uma área de $A = 2 \pi rh + 8r^2$ unidades quadradas. Encontre a proporção entre a altura e o diâmetro para a lata mais econômica (ou seja, que requer a menor quantidade de material para fabricação).

# %% [markdown]
# #Questão 5 - Vale até 1 ponto
#
# Seja a função $ F(x, y) = x^3 + 3x^2y - 2xy^2 + y^3 + \cos(x + 2y)$, encontre as suas derivadas parciais.
#
# A derivada parcial da funcao F em relacao a x e $\frac{∂F}{∂x}$ = $3x^2$ + $6xy$ - $2y^2$ - sin(${x}$+$2y$)
#
# A derivada parcial da funcao F em relacao a y e $\frac{∂F}{∂x}$ = $3x^2$ - $4xy$ + $3y^2$ - 2sin(${x}$ + $2y$)
#
# **Rubrica de Avaliação**: até um ponto se as derivadas forem corretamente encontradas.
